# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cardata = pd.read_csv('turkey_car_market.csv',index_col=0)
cardata.head(5)
# Out:
#               Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# İlan Tarihi
# 27/05/2020   Jaguar             XF  2.0 D Prestige Plus     2017.0
# 16/06/2020    Acura             CL                    -     2015.0
# 14/06/2020    Acura             CL                  2.2     1994.0
# 11/06/2020    Acura             CL                    -     2013.0
# 11/06/2020    Acura             CL                  2.2     2010.0
#
#              Yakıt Turu                Vites           CCM Beygir Gucu  \
# İlan Tarihi
# 27/05/2020        Dizel       Otomatik Vites  1801-2000 cc  176-200 BG
# 16/06/2020        Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG
# 14/06/2020   Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG
# 11/06/2020        Dizel            Düz Vites  1301-1600 cc   76-100 BG
# 11/06/2020        Dizel       Otomatik Vites  1801-2000 cc  151-175 BG
#
#                     Renk         Kasa Tipi      Kimden  Durum      Km   Fiyat
# İlan Tarihi
# ...

# %%
cardata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9044 entries, 27/05/2020 to 04/06/2020
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Marka           9044 non-null   object
#  1   Arac Tip Grubu  9044 non-null   object
#  2   Arac Tip        9044 non-null   object
#  3   Model Yıl       9044 non-null   float64
#  4   Yakıt Turu      9044 non-null   object
#  5   Vites           9044 non-null   object
#  6   CCM             9044 non-null   object
#  7   Beygir Gucu     9044 non-null   object
#  8   Renk            9044 non-null   object
#  9   Kasa Tipi       9044 non-null   object
#  10  Kimden          9044 non-null   object
#  11  Durum           9044 non-null   object
#  12  Km              9044 non-null   int64
#  13  Fiyat           9044 non-null   int64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.0+ MB

# %%
cardata.describe().T
# Out:
#             count           mean            std     min      25%       50%  \
# Model Yıl  9044.0    2011.824082       6.609711  1959.0   2010.0    2014.0
# Km         9044.0  135812.800862   93421.522813     0.0  68000.0  125000.0
# Fiyat      9044.0  148069.638655  221977.857167  5500.0  60937.5   95500.0
#
#                 75%        max
# Model Yıl    2017.0     2020.0
# Km         194130.0  1850000.0
# Fiyat      153562.5  5086500.0

# %%
cardata[['Fiyat','Model Yıl']].groupby(['Fiyat'],as_index=False).mean().sort_values(by='Model Yıl',ascending=False)
# Out:
#         Fiyat    Model Yıl
# 860    132250  2020.000000
# 1798  1700000  2020.000000
# 1759   905000  2020.000000
# 1666   548500  2020.000000
# 1763   937500  2020.000000
# ...       ...          ...
# 102     25999  1987.000000
# 30      14650  1983.000000
# 2        9500  1978.000000
# 206     42250  1973.666667
# 1773  1045000  1961.000000
#
# [1833 rows x 2 columns]

# %%
cardata[['Fiyat','Km']].groupby(['Km'],as_index=False).max().sort_values(by='Fiyat',ascending=False)
# Out:
#           Km    Fiyat
# 1044  140000  5086500
# 0          0  3360000
# 122      900  3250000
# 86       250  2550000
# 286    21861  2495000
# ...      ...      ...
# 948   121212    12250
# 1388  257254    12000
# 76       233    11000
# 77       234    10500
# 141     2222     6250
#
# [1605 rows x 2 columns]

# %%
data = cardata.drop(['Marka','Arac Tip Grubu'
                     ,'Arac Tip','Model Yıl','Yakıt Turu'
                     ,'CCM','Beygir Gucu','Renk','Kasa Tipi'
                     ,'Kimden','Durum','Vites'],axis=1).groupby(['Km']).mean()
data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D96825DC88>],
#       dtype=object)

# %%
cardata[['Marka','Fiyat']].groupby(['Marka'],as_index=False).mean().sort_values(by='Fiyat',ascending=False)
# Out:
#          Marka          Fiyat
# 29     Porsche  966249.821429
# 20  Land Rover  594363.736264
# 16      Jaguar  531438.333333
# 21    Maserati  526740.666667
# 23    Mercedes  316946.249592
# 3          BMW  294943.738636
# 2         Audi  259749.369767
# 14    Infiniti  228390.000000
# 17        Jeep  198877.362637
# 24        Mini  150258.064516
# 26      Nissan  131742.655022
# 33       Skoda  128163.498069
# 0        Acura  123534.523810
# 35  Volkswagen  123500.000000
# 32        Seat  120630.112583
# 15       Isuzu  119788.888889
# 18         Kia  117616.849398
# 1   Alfa Romeo  110961.764706
# 28     Peugeot  107926.505938
# 12       Honda  106489.064639
# 5    Chevrolet   99175.188976
# 13     Hyundai   98060.931142
# 10        Ford   94689.591362
# 6     Chrysler   94126.923077
# 27        Opel   88531.829985
# 30     Renault   85985.257335
# 8        Dacia   81834.671827
# 7      Citroen   79485.165829
# 25  Mitsubishi   77779.687500
# 9         Fiat   68076.585627
# ...

# %%
cardata[['Vites','Fiyat']].groupby(['Vites'],as_index=False).mean().sort_values(by='Fiyat',ascending=False)
# Out:
#                  Vites          Fiyat
# 1       Otomatik Vites  254235.037173
# 2  Yarı Otomatik Vites  192011.412297
# 0            Düz Vites   69794.241441

# %%
data = cardata.drop(['Marka','Arac Tip Grubu'
                     ,'Arac Tip','Model Yıl','Yakıt Turu'
                     ,'CCM','Beygir Gucu','Renk','Kasa Tipi'
                     ,'Kimden','Durum','Km'],axis=1).groupby(['Vites']).mean()
data.head(5)
# Out:
#                              Fiyat
# Vites
# Düz Vites             69794.241441
# Otomatik Vites       254235.037173
# Yarı Otomatik Vites  192011.412297

# %%
data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001829E1B6608>],
#       dtype=object)

# %%
cardata[['Kimden','Fiyat']].groupby(['Kimden'],as_index=False).mean().sort_values(by='Fiyat',ascending=False)
# Out:
#        Kimden          Fiyat
# 0   Galeriden  162167.351910
# 2     Yetkili  144060.447761
# 1  Sahibinden   84212.687654

# %%
data = cardata.drop(['Marka','Arac Tip Grubu'
                     ,'Arac Tip','Model Yıl'
                     ,'CCM','Beygir Gucu','Renk','Kasa Tipi'
                     ,'Durum','Vites'],axis=1).groupby(['Kimden','Yakıt Turu']).mean()
data.head(5)
# Out:
#                                  Km         Fiyat
# Kimden    Yakıt Turu
# Galeriden Benzin       82268.150125  2.417123e+05
#           Benzin/LPG  188133.559548  6.027054e+04
#           Dizel       134126.538804  1.584897e+05
#           Elektrik      5250.000000  9.961250e+05
#           Hibrit       11751.384615  1.665215e+06

# %%
data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000182A1F4D548>,
# ...
#       dtype=object)

# %%
cardata[['Durum','Fiyat']].groupby(['Durum'],as_index=False).mean().sort_values(by='Fiyat',ascending=False)
# Out:
#      Durum          Fiyat
# 0     0 km  601590.040650
# 1    2. El  135947.600411
# 3   Klasik   78400.000000
# 2  Hasarlı   24643.743590

# %%
data = cardata.drop(['Marka','Arac Tip Grubu'
                     ,'Arac Tip','Model Yıl','Yakıt Turu'
                     ,'CCM','Beygir Gucu','Renk','Kasa Tipi'
                     ,'Kimden','Km','Vites'],axis=1).groupby(['Durum']).mean()
data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001591393BDC8>],
#       dtype=object)

# %%
cardata = cardata.dropna()
cardata = pd.get_dummies(cardata)
cardata.head()
# Out:
# ['C:\\Users\\bcaki\\Bc1', 'C:\\Users\\bcaki\\anaconda3\\python37.zip', 'C:\\Users\\bcaki\\anaconda3\\DLLs', 'C:\\Users\\bcaki\\anaconda3\\lib', 'C:\\Users\\bcaki\\anaconda3', '', 'C:\\Users\\bcaki\\AppData\\Roaming\\Python\\Python37\\site-packages', 'C:\\Users\\bcaki\\anaconda3\\lib\\site-packages', 'C:\\Users\\bcaki\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\bcaki\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\bcaki\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\bcaki\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\bcaki\\.ipython']
#              Model Yıl      Km   Fiyat  Marka_Acura  Marka_Alfa Romeo  \
# İlan Tarihi
# 27/05/2020      2017.0   26100  634500            0                 0
# 16/06/2020      2015.0  127000  151500            1                 0
# 14/06/2020      1994.0  175000   19750            1                 0
# 11/06/2020      2013.0     325   52000            1                 0
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn import neighbors
from sklearn.svm import SVR

# %%
def compML(cardata,y,alg):
    y=cardata['Fiyat']
    X=cardata.drop(['Fiyat','Model Yıl','Km'],axis=1).astype('float64')
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=25)
    model = alg().fit(X_train,y_train)
    y_pred=model.predict(X_test)
    RMSE = np.sqrt(mean_squared_error(y_test,y_pred))
    return RMSE

# %%
compML(cardata,'Fiyat',alg)
